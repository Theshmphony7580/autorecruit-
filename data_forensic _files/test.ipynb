# %%
import psutil

print(
    psutil.virtual_memory()
)
# Out:
# svmem(total=12578578432, available=1907281920, percent=84.8, used=10671296512, free=1907281920)

# %%
import os
# import psutil

process = psutil.Process(os.getpid())

print(
    process.memory_info().rss / 1024**3
)
# Out:
# 0.07275772094726562
